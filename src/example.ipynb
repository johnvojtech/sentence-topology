# %%
import matplotlib.pyplot as plt

from sentence_topology.classification.analysis import ClassifierAnalysisResults
from sentence_topology.visualization.predictions import draw_confusion_matrix

# %%
doc2vec_results = ClassifierAnalysisResults.load(
    "../results/best_classifier_analysis-doc2vec-cs-vecsize-512-train-1M-sents.tsv.pkl"
)

# Un-normalized confusion matrix
doc2vec_results.confusion_matrix
# Out:
#                       ban  different meaning  formal sentence  future  \
# ban                    43                  0               14       6
# different meaning       1                  0               32       2
# formal sentence         1                  0              120       8
# future                  0                  0               36     125
# generalization          0                  0               50       8
# minimal change          0                  1               32      11
# nonsense                1                  0               32       4
# nonstandard sentence    0                  0               45       6
# opposite meaning        0                  0               73      18
# paraphrase              1                  0               57       2
# past                    0                  0               51      13
# possibility             1                  0               18       7
# seed                    0                  0               11       2
# simple sentence         0                  0               24       1
#
#                       generalization  minimal change  nonsense  \
# ban                               16               0         0
# different meaning                 33               0         1
# formal sentence                   96               0         0
# future                            44               0         0
# generalization                   246               0         0
# minimal change                    27               0         0
# nonsense                          33               0         0
# nonstandard sentence             117               0         0
# opposite meaning                  96               0         0
# paraphrase                        71               0         0
# past                              38               0         0
# possibility                       23               0         0
# seed                              15               0         0
# simple sentence                   48               0         0
#
#                       nonstandard sentence  opposite meaning  paraphrase  \
# ban                                     24                19           1
# different meaning                       42                15           1
# formal sentence                        119                41           2
# future                                  62                39           1
# generalization                          67                26           2
# minimal change                          40                24           2
# nonsense                                49                18           0
# nonstandard sentence                   318                42           6
# opposite meaning                       103                69           2
# paraphrase                             130                19           1
# past                                    86                30           1
# possibility                             30                25           0
# seed                                    17                12           0
# simple sentence                         50                11           2
#
#                       past  possibility  seed  simple sentence
# ban                      3            0     0                0
# different meaning        3            1     0                0
# formal sentence          5            0     0                0
# future                  11            1     0                0
# generalization           3            2     0                0
# minimal change           5            0     0                0
# nonsense                 5            0     0                0
# nonstandard sentence     6            1     0                0
# opposite meaning        16            3     0                0
# paraphrase              10            1     0                0
# past                    58            2     0                0
# possibility             10           21     0                0
# seed                     5            1     0                0
# simple sentence          2            0     0                0

# %%
fig, axis = plt.subplots(1, 1)
# By default normalizes the matrix before drawing it.
draw_confusion_matrix(doc2vec_results.confusion_matrix, axis)
