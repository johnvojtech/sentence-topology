# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import csv
from numpy.linalg import norm

# %%
## get information of more transformed and less transformed {id:more_tran{},less_tran{}}
## compute the weight for transformation degree
trans_degree = {}
with open('COSTRA1.1.tsv') as f:
  file = csv.reader(f, delimiter ='\t')
  for line in file:
    more_trans = [int(i) for i in line[4].split(",") if len(line[4])!=0]
    less_trans = [int(i) for i in line[5].split(",") if len(line[5])!=0]
    trans_degree[line[0]] = round((len(less_trans)+1)/(len(more_trans)+len(less_trans)+1),2)

# %%
def data_process(file_name):
  seed_dict = {}
  with open(file_name,"r") as file:
    tsv_file = csv.reader(file, delimiter="\t")
    data_dict = {'sent_id':[],'seed_id':[],'label':[],'vec':[]}
    for line in tsv_file:
      data_dict['sent_id'].append(line[0])
      data_dict['seed_id'].append(line[1])
      data_dict['label'].append(line[2])
      data_dict['vec'].append([float(i) for i in line[3:]])
      ## store seed
      if line[2] == 'seed':
        seed_dict[line[1]] = [float(i) for i in line[3:]]
  data_df = pd.DataFrame(data_dict)
  data_df['vec_sub_seed'] = data_df.apply(lambda row: np.array(row['vec']) - np.array(seed_dict[row['seed_id']]),axis=1)
  data_df['degree'] = data_df.apply(lambda row: trans_degree[row['sent_id']],axis= 1)

  return data_df,seed_dict

# %%
## train transfomation vectors for each labels
def get_dist_vec(file_name):
  data_df = data_process(file_name)[0]
  dist_vec = dict()
  labels = data_df['label'].unique()
  for label in labels:
    deriv_class = data_df[data_df['label'] == label]
    ## 80% used for training
    dist_vec[label] = deriv_class.iloc[0:int(len(deriv_class)*0.8)]['vec_sub_seed'].mean()
  return dist_vec

# %%
def test_dist_vec(file_name):
  ## get a cos_sim matrix, sentence_type, test_data_type, value
  data_df,seed_dict = data_process(file_name)
  labels = data_df['label'].unique()
  result = df = pd.DataFrame(columns=labels,index=labels)
  dist_vec = get_dist_vec(file_name)
  for label_sent in labels:
    deriv_class = data_df[data_df['label'] == label_sent]

    ## 20% used for testing
    test_data = deriv_class.iloc[int(len(deriv_class)*0.8):]

    ## computing new transformation sentence, compare with original
    for label_dist in labels:
      test_data['predict_vec'] = test_data.apply(lambda row: np.array(seed_dict[row['seed_id']]) + np.array(dist_vec[label_dist]),axis =1)
      test_data['cos_sim'] = test_data.apply(lambda row:np.dot(np.array(row['vec']),np.array(row['predict_vec']))/(norm(np.array(row['vec'])*norm(np.array(row['predict_vec'])))), axis = 1)
      result.loc[label_sent,label_dist] = test_data['cos_sim'].mean()
  return result

# %%
result = test_dist_vec('bert_vec_unsup.tsv')

# %%
result
# Out:
#                            ban different meaning formal sentence    future  \
# ban                   0.871844          0.793146         0.79122  0.789131
# different meaning      0.85003          0.923477        0.920784  0.909969
# formal sentence       0.829289          0.891663        0.891009  0.877364
# future                0.864927          0.920428         0.91879  0.931696
# generalization        0.631272          0.691736        0.687955   0.68403
# minimal change        0.809584           0.87697        0.874378  0.866275
# nonsense              0.848263           0.92009        0.917355  0.907366
# nonstandard sentence  0.778134          0.844138        0.837897    0.8285
# opposite meaning      0.734323          0.747297        0.744186  0.734799
# paraphrase            0.759156          0.821712        0.819287  0.808685
# past                  0.843112          0.923574        0.919377  0.893505
# possibility           0.873891          0.938457        0.936546  0.939579
# seed                  0.925358          0.999202        0.997436  0.985128
# simple sentence       0.764727          0.825422        0.821679  0.811807
#
#                      generalization minimal change  nonsense  \
# ban                        0.790145       0.790982  0.791761
# different meaning          0.920517       0.923534  0.922951
# formal sentence            0.888005       0.891249  0.891098
# future                       0.9196       0.920248  0.919967
# generalization             0.696534       0.691582  0.692569
# minimal change             0.874877       0.877275  0.876696
# nonsense                   0.917448       0.919957  0.919999
# nonstandard sentence       0.842419        0.84514   0.84411
# opposite meaning           0.743386       0.745999  0.745298
# paraphrase                 0.819826       0.821747  0.821824
# past                       0.916348       0.923395  0.922559
# possibility                0.936593       0.938474  0.938179
# seed                        0.99532        0.99886  0.998643
# simple sentence            0.827105       0.825508  0.825758
#
#                      nonstandard sentence opposite meaning paraphrase  \
# ban                              0.793375         0.821592   0.794079
# different meaning                0.922115         0.908312   0.922635
# formal sentence                  0.888911         0.879878   0.891635
# future                           0.918745         0.909082   0.920158
# generalization                   0.692549         0.672946   0.691128
# minimal change                   0.875943         0.861692   0.876235
# nonsense                         0.918248          0.90467   0.919115
# nonstandard sentence             0.848726         0.827416   0.842634
# opposite meaning                 0.745582         0.758575   0.746946
# paraphrase                       0.821478         0.806916   0.821267
# past                             0.921971         0.907792   0.922286
# possibility                      0.937403         0.922468   0.938245
# seed                             0.996587         0.986143   0.998638
# simple sentence                  0.825966         0.812022   0.824835
#
#                           past possibility      seed simple sentence
# ban                   0.782052    0.788494  0.793061        0.797453
# different meaning     0.915402    0.910619   0.92391        0.921555
# formal sentence       0.885515    0.879954  0.892277        0.889357
# future                0.903692    0.918801  0.921514        0.919268
# generalization        0.687412    0.686614  0.692666        0.692443
# minimal change        0.869938    0.866585  0.877547        0.875088
# nonsense              0.912592    0.907935  0.920077        0.917773
# nonstandard sentence  0.841032    0.834077  0.844624        0.843647
# opposite meaning      0.742519    0.735868   0.74715        0.748007
# paraphrase            0.816591    0.813151  0.822327        0.819816
# past                  0.934856    0.901387  0.923836        0.921007
# possibility           0.925809    0.949993  0.938613        0.936461
# seed                  0.990553    0.983694       1.0        0.997365
# simple sentence       0.821945    0.814637   0.82674        0.827592

# %%
del result['seed']

# %%
result = result.drop('seed')

# %%
result.style.highlight_max(color = 'lightgreen', axis = 1)
# Out:
# <style type="text/css">
# #T_b8376_row0_col0, #T_b8376_row1_col5, #T_b8376_row2_col1, #T_b8376_row3_col3, #T_b8376_row4_col4, #T_b8376_row5_col5, #T_b8376_row6_col1, #T_b8376_row7_col7, #T_b8376_row8_col8, #T_b8376_row9_col6, #T_b8376_row10_col10, #T_b8376_row11_col11, #T_b8376_row12_col12 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b8376" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8376_level0_col0" class="col_heading level0 col0" >ban</th>
#       <th id="T_b8376_level0_col1" class="col_heading level0 col1" >different meaning</th>
#       <th id="T_b8376_level0_col2" class="col_heading level0 col2" >formal sentence</th>
#       <th id="T_b8376_level0_col3" class="col_heading level0 col3" >future</th>
#       <th id="T_b8376_level0_col4" class="col_heading level0 col4" >generalization</th>
#       <th id="T_b8376_level0_col5" class="col_heading level0 col5" >minimal change</th>
#       <th id="T_b8376_level0_col6" class="col_heading level0 col6" >nonsense</th>
#       <th id="T_b8376_level0_col7" class="col_heading level0 col7" >nonstandard sentence</th>
#       <th id="T_b8376_level0_col8" class="col_heading level0 col8" >opposite meaning</th>
#       <th id="T_b8376_level0_col9" class="col_heading level0 col9" >paraphrase</th>
#       <th id="T_b8376_level0_col10" class="col_heading level0 col10" >past</th>
#       <th id="T_b8376_level0_col11" class="col_heading level0 col11" >possibility</th>
#       <th id="T_b8376_level0_col12" class="col_heading level0 col12" >simple sentence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8376_level0_row0" class="row_heading level0 row0" >ban</th>
#       <td id="T_b8376_row0_col0" class="data row0 col0" >0.871844</td>
#       <td id="T_b8376_row0_col1" class="data row0 col1" >0.793146</td>
#       <td id="T_b8376_row0_col2" class="data row0 col2" >0.791220</td>
#       <td id="T_b8376_row0_col3" class="data row0 col3" >0.789131</td>
#       <td id="T_b8376_row0_col4" class="data row0 col4" >0.790145</td>
#       <td id="T_b8376_row0_col5" class="data row0 col5" >0.790982</td>
#       <td id="T_b8376_row0_col6" class="data row0 col6" >0.791761</td>
#       <td id="T_b8376_row0_col7" class="data row0 col7" >0.793375</td>
#       <td id="T_b8376_row0_col8" class="data row0 col8" >0.821592</td>
#       <td id="T_b8376_row0_col9" class="data row0 col9" >0.794079</td>
#       <td id="T_b8376_row0_col10" class="data row0 col10" >0.782052</td>
#       <td id="T_b8376_row0_col11" class="data row0 col11" >0.788494</td>
#       <td id="T_b8376_row0_col12" class="data row0 col12" >0.797453</td>
#     </tr>
#     <tr>
#       <th id="T_b8376_level0_row1" class="row_heading level0 row1" >different meaning</th>
#       <td id="T_b8376_row1_col0" class="data row1 col0" >0.850030</td>
#       <td id="T_b8376_row1_col1" class="data row1 col1" >0.923477</td>
#       <td id="T_b8376_row1_col2" class="data row1 col2" >0.920784</td>
#       <td id="T_b8376_row1_col3" class="data row1 col3" >0.909969</td>
#       <td id="T_b8376_row1_col4" class="data row1 col4" >0.920517</td>
#       <td id="T_b8376_row1_col5" class="data row1 col5" >0.923534</td>
#       <td id="T_b8376_row1_col6" class="data row1 col6" >0.922951</td>
#       <td id="T_b8376_row1_col7" class="data row1 col7" >0.922115</td>
#       <td id="T_b8376_row1_col8" class="data row1 col8" >0.908312</td>
#       <td id="T_b8376_row1_col9" class="data row1 col9" >0.922635</td>
#       <td id="T_b8376_row1_col10" class="data row1 col10" >0.915402</td>
#       <td id="T_b8376_row1_col11" class="data row1 col11" >0.910619</td>
#       <td id="T_b8376_row1_col12" class="data row1 col12" >0.921555</td>
#     </tr>
#     <tr>
#       <th id="T_b8376_level0_row2" class="row_heading level0 row2" >formal sentence</th>
#       <td id="T_b8376_row2_col0" class="data row2 col0" >0.829289</td>
#       <td id="T_b8376_row2_col1" class="data row2 col1" >0.891663</td>
#       <td id="T_b8376_row2_col2" class="data row2 col2" >0.891009</td>
#       <td id="T_b8376_row2_col3" class="data row2 col3" >0.877364</td>
#       <td id="T_b8376_row2_col4" class="data row2 col4" >0.888005</td>
#       <td id="T_b8376_row2_col5" class="data row2 col5" >0.891249</td>
#       <td id="T_b8376_row2_col6" class="data row2 col6" >0.891098</td>
#       <td id="T_b8376_row2_col7" class="data row2 col7" >0.888911</td>
#       <td id="T_b8376_row2_col8" class="data row2 col8" >0.879878</td>
#       <td id="T_b8376_row2_col9" class="data row2 col9" >0.891635</td>
#       <td id="T_b8376_row2_col10" class="data row2 col10" >0.885515</td>
#       <td id="T_b8376_row2_col11" class="data row2 col11" >0.879954</td>
#       <td id="T_b8376_row2_col12" class="data row2 col12" >0.889357</td>
#     </tr>
#     <tr>
#       <th id="T_b8376_level0_row3" class="row_heading level0 row3" >future</th>
#       <td id="T_b8376_row3_col0" class="data row3 col0" >0.864927</td>
#       <td id="T_b8376_row3_col1" class="data row3 col1" >0.920428</td>
#       <td id="T_b8376_row3_col2" class="data row3 col2" >0.918790</td>
#       <td id="T_b8376_row3_col3" class="data row3 col3" >0.931696</td>
#       <td id="T_b8376_row3_col4" class="data row3 col4" >0.919600</td>
#       <td id="T_b8376_row3_col5" class="data row3 col5" >0.920248</td>
#       <td id="T_b8376_row3_col6" class="data row3 col6" >0.919967</td>
#       <td id="T_b8376_row3_col7" class="data row3 col7" >0.918745</td>
#       <td id="T_b8376_row3_col8" class="data row3 col8" >0.909082</td>
#       <td id="T_b8376_row3_col9" class="data row3 col9" >0.920158</td>
#       <td id="T_b8376_row3_col10" class="data row3 col10" >0.903692</td>
#       <td id="T_b8376_row3_col11" class="data row3 col11" >0.918801</td>
#       <td id="T_b8376_row3_col12" class="data row3 col12" >0.919268</td>
#     </tr>
#     <tr>
#       <th id="T_b8376_level0_row4" class="row_heading level0 row4" >generalization</th>
#       <td id="T_b8376_row4_col0" class="data row4 col0" >0.631272</td>
#       <td id="T_b8376_row4_col1" class="data row4 col1" >0.691736</td>
#       <td id="T_b8376_row4_col2" class="data row4 col2" >0.687955</td>
#       <td id="T_b8376_row4_col3" class="data row4 col3" >0.684030</td>
#       <td id="T_b8376_row4_col4" class="data row4 col4" >0.696534</td>
#       <td id="T_b8376_row4_col5" class="data row4 col5" >0.691582</td>
#       <td id="T_b8376_row4_col6" class="data row4 col6" >0.692569</td>
#       <td id="T_b8376_row4_col7" class="data row4 col7" >0.692549</td>
#       <td id="T_b8376_row4_col8" class="data row4 col8" >0.672946</td>
#       <td id="T_b8376_row4_col9" class="data row4 col9" >0.691128</td>
#       <td id="T_b8376_row4_col10" class="data row4 col10" >0.687412</td>
#       <td id="T_b8376_row4_col11" class="data row4 col11" >0.686614</td>
#       <td id="T_b8376_row4_col12" class="data row4 col12" >0.692443</td>
#     </tr>
#     <tr>
#       <th id="T_b8376_level0_row5" class="row_heading level0 row5" >minimal change</th>
#       <td id="T_b8376_row5_col0" class="data row5 col0" >0.809584</td>
#       <td id="T_b8376_row5_col1" class="data row5 col1" >0.876970</td>
#       <td id="T_b8376_row5_col2" class="data row5 col2" >0.874378</td>
#       <td id="T_b8376_row5_col3" class="data row5 col3" >0.866275</td>
#       <td id="T_b8376_row5_col4" class="data row5 col4" >0.874877</td>
#       <td id="T_b8376_row5_col5" class="data row5 col5" >0.877275</td>
#       <td id="T_b8376_row5_col6" class="data row5 col6" >0.876696</td>
#       <td id="T_b8376_row5_col7" class="data row5 col7" >0.875943</td>
#       <td id="T_b8376_row5_col8" class="data row5 col8" >0.861692</td>
#       <td id="T_b8376_row5_col9" class="data row5 col9" >0.876235</td>
#       <td id="T_b8376_row5_col10" class="data row5 col10" >0.869938</td>
#       <td id="T_b8376_row5_col11" class="data row5 col11" >0.866585</td>
#       <td id="T_b8376_row5_col12" class="data row5 col12" >0.875088</td>
#     </tr>
#     <tr>
#       <th id="T_b8376_level0_row6" class="row_heading level0 row6" >nonsense</th>
#       <td id="T_b8376_row6_col0" class="data row6 col0" >0.848263</td>
#       <td id="T_b8376_row6_col1" class="data row6

# %%
result2 = test_dist_vec('LaBSE.tsv')

# %%
del result2['seed']
result2 = result2.drop('seed')

# %%
result2.style.highlight_max(color = 'lightgreen', axis = 1)
# Out:
# <style type="text/css">
# #T_5f478_row0_col0, #T_5f478_row1_col1, #T_5f478_row2_col2, #T_5f478_row3_col3, #T_5f478_row4_col4, #T_5f478_row5_col5, #T_5f478_row6_col6, #T_5f478_row7_col7, #T_5f478_row8_col8, #T_5f478_row9_col1, #T_5f478_row10_col10, #T_5f478_row11_col11, #T_5f478_row12_col12 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5f478" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f478_level0_col0" class="col_heading level0 col0" >ban</th>
#       <th id="T_5f478_level0_col1" class="col_heading level0 col1" >different meaning</th>
#       <th id="T_5f478_level0_col2" class="col_heading level0 col2" >formal sentence</th>
#       <th id="T_5f478_level0_col3" class="col_heading level0 col3" >future</th>
#       <th id="T_5f478_level0_col4" class="col_heading level0 col4" >generalization</th>
#       <th id="T_5f478_level0_col5" class="col_heading level0 col5" >minimal change</th>
#       <th id="T_5f478_level0_col6" class="col_heading level0 col6" >nonsense</th>
#       <th id="T_5f478_level0_col7" class="col_heading level0 col7" >nonstandard sentence</th>
#       <th id="T_5f478_level0_col8" class="col_heading level0 col8" >opposite meaning</th>
#       <th id="T_5f478_level0_col9" class="col_heading level0 col9" >paraphrase</th>
#       <th id="T_5f478_level0_col10" class="col_heading level0 col10" >past</th>
#       <th id="T_5f478_level0_col11" class="col_heading level0 col11" >possibility</th>
#       <th id="T_5f478_level0_col12" class="col_heading level0 col12" >simple sentence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f478_level0_row0" class="row_heading level0 row0" >ban</th>
#       <td id="T_5f478_row0_col0" class="data row0 col0" >0.908636</td>
#       <td id="T_5f478_row0_col1" class="data row0 col1" >0.856270</td>
#       <td id="T_5f478_row0_col2" class="data row0 col2" >0.856759</td>
#       <td id="T_5f478_row0_col3" class="data row0 col3" >0.852592</td>
#       <td id="T_5f478_row0_col4" class="data row0 col4" >0.847226</td>
#       <td id="T_5f478_row0_col5" class="data row0 col5" >0.856818</td>
#       <td id="T_5f478_row0_col6" class="data row0 col6" >0.852912</td>
#       <td id="T_5f478_row0_col7" class="data row0 col7" >0.852621</td>
#       <td id="T_5f478_row0_col8" class="data row0 col8" >0.872373</td>
#       <td id="T_5f478_row0_col9" class="data row0 col9" >0.857920</td>
#       <td id="T_5f478_row0_col10" class="data row0 col10" >0.841320</td>
#       <td id="T_5f478_row0_col11" class="data row0 col11" >0.861245</td>
#       <td id="T_5f478_row0_col12" class="data row0 col12" >0.856496</td>
#     </tr>
#     <tr>
#       <th id="T_5f478_level0_row1" class="row_heading level0 row1" >different meaning</th>
#       <td id="T_5f478_row1_col0" class="data row1 col0" >0.869263</td>
#       <td id="T_5f478_row1_col1" class="data row1 col1" >0.913549</td>
#       <td id="T_5f478_row1_col2" class="data row1 col2" >0.911573</td>
#       <td id="T_5f478_row1_col3" class="data row1 col3" >0.895953</td>
#       <td id="T_5f478_row1_col4" class="data row1 col4" >0.904120</td>
#       <td id="T_5f478_row1_col5" class="data row1 col5" >0.913539</td>
#       <td id="T_5f478_row1_col6" class="data row1 col6" >0.912387</td>
#       <td id="T_5f478_row1_col7" class="data row1 col7" >0.908771</td>
#       <td id="T_5f478_row1_col8" class="data row1 col8" >0.908171</td>
#       <td id="T_5f478_row1_col9" class="data row1 col9" >0.912600</td>
#       <td id="T_5f478_row1_col10" class="data row1 col10" >0.902856</td>
#       <td id="T_5f478_row1_col11" class="data row1 col11" >0.891687</td>
#       <td id="T_5f478_row1_col12" class="data row1 col12" >0.911063</td>
#     </tr>
#     <tr>
#       <th id="T_5f478_level0_row2" class="row_heading level0 row2" >formal sentence</th>
#       <td id="T_5f478_row2_col0" class="data row2 col0" >0.840812</td>
#       <td id="T_5f478_row2_col1" class="data row2 col1" >0.881631</td>
#       <td id="T_5f478_row2_col2" class="data row2 col2" >0.882586</td>
#       <td id="T_5f478_row2_col3" class="data row2 col3" >0.863858</td>
#       <td id="T_5f478_row2_col4" class="data row2 col4" >0.872444</td>
#       <td id="T_5f478_row2_col5" class="data row2 col5" >0.881459</td>
#       <td id="T_5f478_row2_col6" class="data row2 col6" >0.879007</td>
#       <td id="T_5f478_row2_col7" class="data row2 col7" >0.874732</td>
#       <td id="T_5f478_row2_col8" class="data row2 col8" >0.879097</td>
#       <td id="T_5f478_row2_col9" class="data row2 col9" >0.881547</td>
#       <td id="T_5f478_row2_col10" class="data row2 col10" >0.875011</td>
#       <td id="T_5f478_row2_col11" class="data row2 col11" >0.857639</td>
#       <td id="T_5f478_row2_col12" class="data row2 col12" >0.879454</td>
#     </tr>
#     <tr>
#       <th id="T_5f478_level0_row3" class="row_heading level0 row3" >future</th>
#       <td id="T_5f478_row3_col0" class="data row3 col0" >0.865414</td>
#       <td id="T_5f478_row3_col1" class="data row3 col1" >0.894271</td>
#       <td id="T_5f478_row3_col2" class="data row3 col2" >0.892775</td>
#       <td id="T_5f478_row3_col3" class="data row3 col3" >0.911796</td>
#       <td id="T_5f478_row3_col4" class="data row3 col4" >0.884285</td>
#       <td id="T_5f478_row3_col5" class="data row3 col5" >0.894816</td>
#       <td id="T_5f478_row3_col6" class="data row3 col6" >0.892792</td>
#       <td id="T_5f478_row3_col7" class="data row3 col7" >0.891723</td>
#       <td id="T_5f478_row3_col8" class="data row3 col8" >0.891624</td>
#       <td id="T_5f478_row3_col9" class="data row3 col9" >0.894266</td>
#       <td id="T_5f478_row3_col10" class="data row3 col10" >0.877093</td>
#       <td id="T_5f478_row3_col11" class="data row3 col11" >0.884111</td>
#       <td id="T_5f478_row3_col12" class="data row3 col12" >0.892260</td>
#     </tr>
#     <tr>
#       <th id="T_5f478_level0_row4" class="row_heading level0 row4" >generalization</th>
#       <td id="T_5f478_row4_col0" class="data row4 col0" >0.620812</td>
#       <td id="T_5f478_row4_col1" class="data row4 col1" >0.653563</td>
#       <td id="T_5f478_row4_col2" class="data row4 col2" >0.650912</td>
#       <td id="T_5f478_row4_col3" class="data row4 col3" >0.637312</td>
#       <td id="T_5f478_row4_col4" class="data row4 col4" >0.662165</td>
#       <td id="T_5f478_row4_col5" class="data row4 col5" >0.651367</td>
#       <td id="T_5f478_row4_col6" class="data row4 col6" >0.649258</td>
#       <td id="T_5f478_row4_col7" class="data row4 col7" >0.640523</td>
#       <td id="T_5f478_row4_col8" class="data row4 col8" >0.653384</td>
#       <td id="T_5f478_row4_col9" class="data row4 col9" >0.651273</td>
#       <td id="T_5f478_row4_col10" class="data row4 col10" >0.647594</td>
#       <td id="T_5f478_row4_col11" class="data row4 col11" >0.636617</td>
#       <td id="T_5f478_row4_col12" class="data row4 col12" >0.660528</td>
#     </tr>
#     <tr>
#       <th id="T_5f478_level0_row5" class="row_heading level0 row5" >minimal change</th>
#       <td id="T_5f478_row5_col0" class="data row5 col0" >0.872378</td>
#       <td id="T_5f478_row5_col1" class="data row5 col1" >0.916100</td>
#       <td id="T_5f478_row5_col2" class="data row5 col2" >0.914638</td>
#       <td id="T_5f478_row5_col3" class="data row5 col3" >0.901427</td>
#       <td id="T_5f478_row5_col4" class="data row5 col4" >0.906769</td>
#       <td id="T_5f478_row5_col5" class="data row5 col5" >0.916517</td>
#       <td id="T_5f478_row5_col6" class="data row5 col6" >0.914810</td>
#       <td id="T_5f478_row5_col7" class="data row5 col7" >0.912244</td>
#       <td id="T_5f478_row5_col8" class="data row5 col8" >0.911212</td>
#       <td id="T_5f478_row5_col9" class="data row5 col9" >0.915564</td>
#       <td id="T_5f478_row5_col10" class="data row5 col10" >0.906616</td>
#       <td id="T_5f478_row5_col11" class="data row5 col11" >0.892418</td>
#       <td id="T_5f478_row5_col12" class="data row5 col12" >0.913911</td>
#     </tr>
#     <tr>
#       <th id="T_5f478_level0_row6" class="row_heading level0 row6" >nonsense</th>
#       <td id="T_5f478_row6_col0" class="data row6 col0" >0.859517</td>
#       <td id="T_5f478_row6_col1" class="data row6

# %%
result3 = test_dist_vec('Phrase_Embedding.tsv')

# %%
del result3['seed']
result3 = result3.drop('seed')
result3.style.highlight_max(color = 'lightgreen', axis = 1)
# Out:
# <style type="text/css">
# #T_6c4b8_row0_col0, #T_6c4b8_row1_col5, #T_6c4b8_row2_col2, #T_6c4b8_row3_col3, #T_6c4b8_row4_col4, #T_6c4b8_row5_col5, #T_6c4b8_row6_col6, #T_6c4b8_row7_col7, #T_6c4b8_row8_col8, #T_6c4b8_row9_col9, #T_6c4b8_row10_col10, #T_6c4b8_row11_col11, #T_6c4b8_row12_col7 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6c4b8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c4b8_level0_col0" class="col_heading level0 col0" >ban</th>
#       <th id="T_6c4b8_level0_col1" class="col_heading level0 col1" >different meaning</th>
#       <th id="T_6c4b8_level0_col2" class="col_heading level0 col2" >formal sentence</th>
#       <th id="T_6c4b8_level0_col3" class="col_heading level0 col3" >future</th>
#       <th id="T_6c4b8_level0_col4" class="col_heading level0 col4" >generalization</th>
#       <th id="T_6c4b8_level0_col5" class="col_heading level0 col5" >minimal change</th>
#       <th id="T_6c4b8_level0_col6" class="col_heading level0 col6" >nonsense</th>
#       <th id="T_6c4b8_level0_col7" class="col_heading level0 col7" >nonstandard sentence</th>
#       <th id="T_6c4b8_level0_col8" class="col_heading level0 col8" >opposite meaning</th>
#       <th id="T_6c4b8_level0_col9" class="col_heading level0 col9" >paraphrase</th>
#       <th id="T_6c4b8_level0_col10" class="col_heading level0 col10" >past</th>
#       <th id="T_6c4b8_level0_col11" class="col_heading level0 col11" >possibility</th>
#       <th id="T_6c4b8_level0_col12" class="col_heading level0 col12" >simple sentence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c4b8_level0_row0" class="row_heading level0 row0" >ban</th>
#       <td id="T_6c4b8_row0_col0" class="data row0 col0" >0.985117</td>
#       <td id="T_6c4b8_row0_col1" class="data row0 col1" >0.982955</td>
#       <td id="T_6c4b8_row0_col2" class="data row0 col2" >0.982624</td>
#       <td id="T_6c4b8_row0_col3" class="data row0 col3" >0.982101</td>
#       <td id="T_6c4b8_row0_col4" class="data row0 col4" >0.980696</td>
#       <td id="T_6c4b8_row0_col5" class="data row0 col5" >0.983186</td>
#       <td id="T_6c4b8_row0_col6" class="data row0 col6" >0.983111</td>
#       <td id="T_6c4b8_row0_col7" class="data row0 col7" >0.982632</td>
#       <td id="T_6c4b8_row0_col8" class="data row0 col8" >0.983580</td>
#       <td id="T_6c4b8_row0_col9" class="data row0 col9" >0.983006</td>
#       <td id="T_6c4b8_row0_col10" class="data row0 col10" >0.982865</td>
#       <td id="T_6c4b8_row0_col11" class="data row0 col11" >0.981886</td>
#       <td id="T_6c4b8_row0_col12" class="data row0 col12" >0.982179</td>
#     </tr>
#     <tr>
#       <th id="T_6c4b8_level0_row1" class="row_heading level0 row1" >different meaning</th>
#       <td id="T_6c4b8_row1_col0" class="data row1 col0" >0.984255</td>
#       <td id="T_6c4b8_row1_col1" class="data row1 col1" >0.985877</td>
#       <td id="T_6c4b8_row1_col2" class="data row1 col2" >0.985268</td>
#       <td id="T_6c4b8_row1_col3" class="data row1 col3" >0.985034</td>
#       <td id="T_6c4b8_row1_col4" class="data row1 col4" >0.983727</td>
#       <td id="T_6c4b8_row1_col5" class="data row1 col5" >0.985932</td>
#       <td id="T_6c4b8_row1_col6" class="data row1 col6" >0.985931</td>
#       <td id="T_6c4b8_row1_col7" class="data row1 col7" >0.985197</td>
#       <td id="T_6c4b8_row1_col8" class="data row1 col8" >0.985810</td>
#       <td id="T_6c4b8_row1_col9" class="data row1 col9" >0.985766</td>
#       <td id="T_6c4b8_row1_col10" class="data row1 col10" >0.985591</td>
#       <td id="T_6c4b8_row1_col11" class="data row1 col11" >0.983822</td>
#       <td id="T_6c4b8_row1_col12" class="data row1 col12" >0.985249</td>
#     </tr>
#     <tr>
#       <th id="T_6c4b8_level0_row2" class="row_heading level0 row2" >formal sentence</th>
#       <td id="T_6c4b8_row2_col0" class="data row2 col0" >0.965474</td>
#       <td id="T_6c4b8_row2_col1" class="data row2 col1" >0.967207</td>
#       <td id="T_6c4b8_row2_col2" class="data row2 col2" >0.967907</td>
#       <td id="T_6c4b8_row2_col3" class="data row2 col3" >0.966841</td>
#       <td id="T_6c4b8_row2_col4" class="data row2 col4" >0.963156</td>
#       <td id="T_6c4b8_row2_col5" class="data row2 col5" >0.967432</td>
#       <td id="T_6c4b8_row2_col6" class="data row2 col6" >0.967267</td>
#       <td id="T_6c4b8_row2_col7" class="data row2 col7" >0.965947</td>
#       <td id="T_6c4b8_row2_col8" class="data row2 col8" >0.967066</td>
#       <td id="T_6c4b8_row2_col9" class="data row2 col9" >0.967534</td>
#       <td id="T_6c4b8_row2_col10" class="data row2 col10" >0.967522</td>
#       <td id="T_6c4b8_row2_col11" class="data row2 col11" >0.964687</td>
#       <td id="T_6c4b8_row2_col12" class="data row2 col12" >0.965403</td>
#     </tr>
#     <tr>
#       <th id="T_6c4b8_level0_row3" class="row_heading level0 row3" >future</th>
#       <td id="T_6c4b8_row3_col0" class="data row3 col0" >0.977580</td>
#       <td id="T_6c4b8_row3_col1" class="data row3 col1" >0.979350</td>
#       <td id="T_6c4b8_row3_col2" class="data row3 col2" >0.979246</td>
#       <td id="T_6c4b8_row3_col3" class="data row3 col3" >0.980029</td>
#       <td id="T_6c4b8_row3_col4" class="data row3 col4" >0.975887</td>
#       <td id="T_6c4b8_row3_col5" class="data row3 col5" >0.979507</td>
#       <td id="T_6c4b8_row3_col6" class="data row3 col6" >0.979368</td>
#       <td id="T_6c4b8_row3_col7" class="data row3 col7" >0.978468</td>
#       <td id="T_6c4b8_row3_col8" class="data row3 col8" >0.979178</td>
#       <td id="T_6c4b8_row3_col9" class="data row3 col9" >0.979437</td>
#       <td id="T_6c4b8_row3_col10" class="data row3 col10" >0.979377</td>
#       <td id="T_6c4b8_row3_col11" class="data row3 col11" >0.977477</td>
#       <td id="T_6c4b8_row3_col12" class="data row3 col12" >0.978025</td>
#     </tr>
#     <tr>
#       <th id="T_6c4b8_level0_row4" class="row_heading level0 row4" >generalization</th>
#       <td id="T_6c4b8_row4_col0" class="data row4 col0" >0.922534</td>
#       <td id="T_6c4b8_row4_col1" class="data row4 col1" >0.922989</td>
#       <td id="T_6c4b8_row4_col2" class="data row4 col2" >0.921744</td>
#       <td id="T_6c4b8_row4_col3" class="data row4 col3" >0.921497</td>
#       <td id="T_6c4b8_row4_col4" class="data row4 col4" >0.924773</td>
#       <td id="T_6c4b8_row4_col5" class="data row4 col5" >0.923049</td>
#       <td id="T_6c4b8_row4_col6" class="data row4 col6" >0.923315</td>
#       <td id="T_6c4b8_row4_col7" class="data row4 col7" >0.922815</td>
#       <td id="T_6c4b8_row4_col8" class="data row4 col8" >0.923849</td>
#       <td id="T_6c4b8_row4_col9" class="data row4 col9" >0.922826</td>
#       <td id="T_6c4b8_row4_col10" class="data row4 col10" >0.922001</td>
#       <td id="T_6c4b8_row4_col11" class="data row4 col11" >0.921211</td>
#       <td id="T_6c4b8_row4_col12" class="data row4 col12" >0.924037</td>
#     </tr>
#     <tr>
#       <th id="T_6c4b8_level0_row5" class="row_heading level0 row5" >minimal change</th>
#       <td id="T_6c4b8_row5_col0" class="data row5 col0" >0.984193</td>
#       <td id="T_6c4b8_row5_col1" class="data row5 col1" >0.986001</td>
#       <td id="T_6c4b8_row5_col2" class="data row5 col2" >0.985614</td>
#       <td id="T_6c4b8_row5_col3" class="data row5 col3" >0.985461</td>
#       <td id="T_6c4b8_row5_col4" class="data row5 col4" >0.983187</td>
#       <td id="T_6c4b8_row5_col5" class="data row5 col5" >0.986114</td>
#       <td id="T_6c4b8_row5_col6" class="data row5 col6" >0.986003</td>
#       <td id="T_6c4b8_row5_col7" class="data row5 col7" >0.985321</td>
#       <td id="T_6c4b8_row5_col8" class="data row5 col8" >0.985865</td>
#       <td id="T_6c4b8_row5_col9" class="data row5 col9" >0.986001</td>
#       <td id="T_6c4b8_row5_col10" class="data row5 col10" >0.985984</td>
#       <td id="T_6c4b8_row5_col11" class="data row5 col11" >0.984010</td>
#       <td id="T_6c4b8_row5_col12" class="data row5 col12" >0.985152</td>
#     </tr>
#     <tr>
#       <th id="T_6c4b8_level0_row6" class="row_heading level0 row6" >nonsense</th>
#       <td id="T_6c4b8_row6_col0" class="data row6 col0" >0.982275</td>
#       <td id="T_6c4b8_row6_col1" class="data row6

# %% [markdown]
# #The codes below are from past and no longer useful

# %%
def compute_cos(label):
  deriv_class = data_df[data_df['label'] == label]
  split = int(len(deriv_class)*0.8)
  dist_vec = deriv_class.iloc[0:split]['vec_sub_seed'].mean()

  test = deriv_class.iloc[split:]

  ## predict the vec by computing seed + dist
  test['predict_vec'] = test.apply(lambda row: np.array(seed_dict[row['seed_id']]) + np.array(dist_vec),axis =1)
  test['cos_sim'] = test.apply(lambda row:np.dot(np.array(row['vec']),np.array(row['predict_vec']))/(norm(np.array(row['vec'])*norm(np.array(row['predict_vec'])))), axis = 1)
  ## compare with vec(true) and predicted_vec, cosine similarity
  return test['cos_sim'].mean()

# %%
data_df, seed_dict= data_process('bert_vec_unsup.tsv')
labels = data_df['label'].unique()
result = []
for label in labels:
  result.append([label,compute_cos(label)])
result.sort(key=lambda row: row[1],reverse=True)

# %%
# import module
from tabulate import tabulate

# create header
head = ['label', "cos_similarity"]

# display table
print(tabulate(result, headers=head, tablefmt="grid"))
# Out:
# +----------------------+------------------+
# | label                |   cos_similarity |
# +======================+==================+
# | seed                 |         1        |
# +----------------------+------------------+
# | possibility          |         0.949993 |
# +----------------------+------------------+
# | past                 |         0.934856 |
# +----------------------+------------------+
# | future               |         0.931696 |
# +----------------------+------------------+
# | different meaning    |         0.923477 |
# +----------------------+------------------+
# | nonsense             |         0.919999 |
# +----------------------+------------------+
# | formal sentence      |         0.891009 |
# +----------------------+------------------+
# | minimal change       |         0.877275 |
# +----------------------+------------------+
# | ban                  |         0.871844 |
# +----------------------+------------------+
# | nonstandard sentence |         0.848726 |
# +----------------------+------------------+
# | simple sentence      |         0.827592 |
# +----------------------+------------------+
# | paraphrase           |         0.821267 |
# +----------------------+------------------+
# | opposite meaning     |         0.758575 |
# +----------------------+------------------+
# | generalization       |         0.696534 |
# +----------------------+------------------+

# %%
data_df, seed_dict= data_process('LaBSE.tsv')
result = []
labels = data_df['label'].unique()
for label in labels:
  result.append([label,compute_cos(label)])

result.sort(key=lambda row: row[1],reverse=True)

# %%
from tabulate import tabulate
# create header
head = ['label', "cos_similarity"]

# display table
print(tabulate(result, headers=head, tablefmt="grid"))
# Out:
# +----------------------+------------------+
# | label                |   cos_similarity |
# +======================+==================+
# | seed                 |         1        |
# +----------------------+------------------+
# | possibility          |         0.945029 |
# +----------------------+------------------+
# | minimal change       |         0.916517 |
# +----------------------+------------------+
# | different meaning    |         0.913549 |
# +----------------------+------------------+
# | future               |         0.911796 |
# +----------------------+------------------+
# | past                 |         0.909999 |
# +----------------------+------------------+
# | ban                  |         0.908636 |
# +----------------------+------------------+
# | nonsense             |         0.904608 |
# +----------------------+------------------+
# | formal sentence      |         0.882586 |
# +----------------------+------------------+
# | opposite meaning     |         0.826481 |
# +----------------------+------------------+
# | nonstandard sentence |         0.824879 |
# +----------------------+------------------+
# | paraphrase           |         0.813986 |
# +----------------------+------------------+
# | simple sentence      |         0.790896 |
# +----------------------+------------------+
# | generalization       |         0.662165 |
# +----------------------+------------------+

# %%
data_df, seed_dict= data_process('Phrase_Embedding.tsv')
result = []
labels = data_df['label'].unique()
for label in labels:
  result.append([label,compute_cos(label)])

result.sort(key=lambda row: row[1],reverse=True)

# %%
from tabulate import tabulate
# create header
head = ['label', "cos_similarity"]

# display table
print(tabulate(result, headers=head, tablefmt="grid"))
# Out:
# +----------------------+------------------+
# | label                |   cos_similarity |
# +======================+==================+
# | seed                 |         1        |
# +----------------------+------------------+
# | minimal change       |         0.986114 |
# +----------------------+------------------+
# | different meaning    |         0.985877 |
# +----------------------+------------------+
# | ban                  |         0.985117 |
# +----------------------+------------------+
# | possibility          |         0.984613 |
# +----------------------+------------------+
# | nonsense             |         0.984205 |
# +----------------------+------------------+
# | past                 |         0.98225  |
# +----------------------+------------------+
# | future               |         0.980029 |
# +----------------------+------------------+
# | formal sentence      |         0.967907 |
# +----------------------+------------------+
# | opposite meaning     |         0.967047 |
# +----------------------+------------------+
# | nonstandard sentence |         0.958693 |
# +----------------------+------------------+
# | paraphrase           |         0.950207 |
# +----------------------+------------------+
# | simple sentence      |         0.943055 |
# +----------------------+------------------+
# | generalization       |         0.924773 |
# +----------------------+------------------+

# %%
data_df, seed_dict= data_process('mixup_by_seed_bert_unsup.tsv')
result = []
labels = data_df['label'].unique()
for label in labels:
  result.append([label,compute_cos(label)])

result.sort(key=lambda row: row[1],reverse=True)

# %%
from tabulate import tabulate
# create header
head = ['label', "cos_similarity"]

# display table
print(tabulate(result, headers=head, tablefmt="grid"))
# Out:
# +----------------------+------------------+
# | label                |   cos_similarity |
# +======================+==================+
# | seed                 |         1        |
# +----------------------+------------------+
# | different meaning    |         0.787777 |
# +----------------------+------------------+
# | possibility          |         0.777093 |
# +----------------------+------------------+
# | nonstandard sentence |         0.771835 |
# +----------------------+------------------+
# | opposite meaning     |         0.771732 |
# +----------------------+------------------+
# | future               |         0.762693 |
# +----------------------+------------------+
# | past                 |         0.761243 |
# +----------------------+------------------+
# | formal sentence      |         0.759873 |
# +----------------------+------------------+
# | paraphrase           |         0.755519 |
# +----------------------+------------------+
# | generalization       |         0.751795 |
# +----------------------+------------------+
# | nonsense             |         0.749469 |
# +----------------------+------------------+
# | ban                  |         0.749008 |
# +----------------------+------------------+
# | minimal change       |         0.747322 |
# +----------------------+------------------+
# | simple sentence      |         0.725943 |
# +----------------------+------------------+

# %%
data_df, seed_dict= data_process('doc2vec_vsize_256.tsv')
result = []
labels = data_df['label'].unique()
for label in labels:
  result.append([label,compute_cos(label)])

result.sort(key=lambda row: row[1],reverse=True)

# %%
from tabulate import tabulate
# create header
head = ['label', "cos_similarity"]

# display table
print(tabulate(result, headers=head, tablefmt="grid"))
# Out:
# +----------------------+------------------+
# | label                |   cos_similarity |
# +======================+==================+
# | seed                 |         1        |
# +----------------------+------------------+
# | minimal change       |         0.649096 |
# +----------------------+------------------+
# | possibility          |         0.620002 |
# +----------------------+------------------+
# | past                 |         0.575301 |
# +----------------------+------------------+
# | future               |         0.566623 |
# +----------------------+------------------+
# | different meaning    |         0.542322 |
# +----------------------+------------------+
# | ban                  |         0.534627 |
# +----------------------+------------------+
# | nonsense             |         0.470186 |
# +----------------------+------------------+
# | opposite meaning     |         0.44971  |
# +----------------------+------------------+
# | formal sentence      |         0.442651 |
# +----------------------+------------------+
# | nonstandard sentence |         0.387551 |
# +----------------------+------------------+
# | simple sentence      |         0.351131 |
# +----------------------+------------------+
# | paraphrase           |         0.302725 |
# +----------------------+------------------+
# | generalization       |         0.29159  |
# +----------------------+------------------+

# %%
data_df, seed_dict= data_process('mixup_by_seed_bert_unsup.tsv')
result = []
for label in labels:
  result.append([label,compute_cos(label)])

# %%
labels = data_df['label'].unique()
result.sort(key=lambda row: row[1],reverse=True)

# %%
# import module
from tabulate import tabulate

# create header
head = ['label', "cos_similarity"]

# display table
print(tabulate(result, headers=head, tablefmt="grid"))
# Out:
# +----------------------+------------------+
# | label                |   cos_similarity |
# +======================+==================+
# | seed                 |         1        |
# +----------------------+------------------+
# | possibility          |         0.936635 |
# +----------------------+------------------+
# | past                 |         0.930636 |
# +----------------------+------------------+
# | future               |         0.923555 |
# +----------------------+------------------+
# | different meaning    |         0.913798 |
# +----------------------+------------------+
# | nonsense             |         0.901452 |
# +----------------------+------------------+
# | formal sentence      |         0.882741 |
# +----------------------+------------------+
# | minimal change       |         0.866246 |
# +----------------------+------------------+
# | ban                  |         0.845272 |
# +----------------------+------------------+
# | paraphrase           |         0.81659  |
# +----------------------+------------------+
# | nonstandard sentence |         0.812346 |
# +----------------------+------------------+
# | simple sentence      |         0.807523 |
# +----------------------+------------------+
# | opposite meaning     |         0.748853 |
# +----------------------+------------------+
# | generalization       |         0.697715 |
# +----------------------+------------------+
